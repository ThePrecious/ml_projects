# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai import *
from fastai.vision import *
from pathlib import Path

# %%
#!pip install librosa

# %% [markdown]
# ## SPECTROGRAM

# %%
spectrogram_path = Path('/home/ec2-user/SageMaker/course-v3/nbs/personal_projects/Music_Mood_Classification/spectrogram2')

# %%
label_path  = Path('/home/ec2-user/SageMaker/course-v3/nbs/personal_projects/Music_Mood_Classification/input_label.csv')

# %%
str(label_path.name)
# Out:
# 'input_label.csv'

# %%
data = ImageDataBunch.from_csv(spectrogram_path.parent,
                               spectrogram_path.name, 
                               csv_labels = str(label_path), suffix='.png',size=224)
#data.normalize(imagenet_stats)

# %%
data.normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
data.train_dl.one_batch()[0].shape
# Out:
# torch.Size([64, 3, 224, 224])

# %%
print(data.classes)
# Out:
# ['Happy', 'Angry', 'Tender', 'Sad', 'Funny', 'Scary']

# %%
len(data.classes),data.c
# Out:
# (6, 6)

# %%
from  fastai.vision import models
learn = create_cnn(data, models.resnet34, metrics=[error_rate, accuracy])
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10, 1e-2)
# Out:
# Total time: 10:09
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      1.286524    1.077143    0.427078    0.572922  (01:00)
# 2      1.065306    1.078124    0.442755    0.557245  (01:00)
# 3      1.045786    1.149348    0.448931    0.551069  (01:00)
# 4      1.011586    0.988076    0.393824    0.606176  (01:00)
# 5      0.979079    1.013643    0.424228    0.575772  (01:00)
# 6      0.927784    1.067985    0.449881    0.550119  (01:00)
# 7      0.867401    0.984401    0.398100    0.601900  (01:00)
# 8      0.788149    0.967622    0.381948    0.618052  (01:00)
# 9      0.695708    0.993058    0.386223    0.613777  (01:00)
# 10     0.636436    1.001889    0.381473    0.618527  (01:00)

# %%
learn.fit_one_cycle(10, 1e-1)
# Out:
# Total time: 10:02
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      1.067259    1.789711    0.570071    0.429929  (01:00)
# 2      1.383312    1.846019    0.544418    0.455582  (01:00)
# 3      1.537553    2.172557    0.578622    0.421378  (01:00)
# 4      1.551232    53.033222   0.810926    0.189074  (01:00)
# 5      1.484146    1.288987    0.533017    0.466983  (00:59)
# 6      1.248325    1.081453    0.460808    0.539192  (01:00)
# 7      1.133652    5.958066    0.451306    0.548694  (01:00)
# 8      1.025177    1.857084    0.400475    0.599525  (01:00)
# 9      0.943719    2.988311    0.399050    0.600950  (01:00)
# 10     0.889547    1.871235    0.387648    0.612352  (01:00)

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10, max_lr=slice(1e-5,5*1e-5))
# Out:
# Total time: 14:17
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.465767    1.219787    0.414727    0.585273  (01:25)
# 2      0.457260    1.245059    0.417577    0.582423  (01:25)
# 3      0.417050    1.308733    0.429929    0.570071  (01:25)
# 4      0.321014    1.319825    0.420428    0.579572  (01:25)
# 5      0.225334    1.399403    0.435154    0.564846  (01:25)
# 6      0.157343    1.497511    0.423278    0.576722  (01:25)
# 7      0.100889    1.489651    0.433254    0.566746  (01:25)
# 8      0.077949    1.516427    0.426128    0.573872  (01:25)
# 9      0.060823    1.548691    0.429929    0.570071  (01:25)
# 10     0.055824    1.558732    0.429929    0.570071  (01:25)

# %%
learn.freeze()
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10, 1e-3)
# Out:
# Total time: 10:08
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.045042    1.732156    0.432304    0.567696  (01:00)
# 2      0.031357    2.137498    0.431829    0.568171  (01:00)
# 3      0.028667    2.490355    0.441805    0.558195  (01:00)
# 4      0.039953    2.765464    0.440380    0.559620  (01:00)
# 5      0.031163    2.805558    0.439430    0.560570  (01:00)
# 6      0.026128    2.885876    0.432779    0.567221  (01:00)
# 7      0.021433    3.038012    0.429454    0.570546  (01:00)
# 8      0.018143    2.990960    0.438005    0.561995  (01:00)
# 9      0.014829    3.032969    0.436580    0.563420  (01:00)
# 10     0.014176    3.006571    0.431354    0.568646  (01:00)

# %% [markdown]
# ## MELSPECTROGRAM

# %%
melspectrogram_path = Path('/home/ec2-user/SageMaker/course-v3/nbs/personal_projects/Music_Mood_Classification/MelSpectrogram')

# %%
label_path  = Path('/home/ec2-user/SageMaker/course-v3/nbs/personal_projects/Music_Mood_Classification/input_label.csv')

# %%
data = ImageDataBunch.from_csv(melspectrogram_path.parent,
                               melspectrogram_path.name, 
                               csv_labels = str(label_path), suffix='.png',size=224)

# %%
data.normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
data.train_dl.one_batch()[0].shape
# Out:
# torch.Size([64, 3, 224, 224])

# %%
from  fastai.vision import models
learnM = create_cnn(data, models.resnet34, metrics=[error_rate, accuracy])
learnM.lr_find()
learnM.recorder.plot()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learnM.fit_one_cycle(10, 1e-3) # NOT GOOD , did not run today
# Out:
# Total time: 10:09
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.568421    0.895216    0.336898    0.663102  (01:00)
# 2      0.584960    0.939097    0.346621    0.653379  (01:00)
# 3      0.552036    0.947226    0.341760    0.658240  (01:00)
# 4      0.540132    0.963506    0.353427    0.646573  (01:00)
# 5      0.505343    0.986945    0.346621    0.653379  (01:00)
# 6      0.499114    1.024585    0.358289    0.641711  (01:01)
# 7      0.461420    1.060657    0.363636    0.636364  (01:01)
# 8      0.432151    1.082425    0.365581    0.634419  (01:00)
# 9      0.408888    1.089065    0.359747    0.640253  (01:00)
# 10     0.400317    1.098842    0.364609    0.635391  (01:01)

# %%
learnM.fit_one_cycle(10, 1e-2) #NOT GOOD , did not run today
# Out:
# Total time: 10:08
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.520471    1.023040    0.357803    0.642197  (01:00)
# 2      0.673103    1.199551    0.411279    0.588721  (01:01)
# 3      0.776581    1.175358    0.387944    0.612056  (01:00)
# 4      0.803569    0.997600    0.380651    0.619349  (01:01)
# 5      0.795893    0.916712    0.367039    0.632961  (01:00)
# 6      0.741264    1.028973    0.387944    0.612056  (01:00)
# 7      0.688454    0.921565    0.356830    0.643170  (01:00)
# 8      0.579683    0.937582    0.348566    0.651434  (01:00)
# 9      0.476522    0.999282    0.341760    0.658240  (01:00)
# 10     0.412369    1.014351    0.351483    0.648517  (01:00)

# %%
learnM.fit_one_cycle(10, max_lr=slice(1e-2,5*1e-2)) #did not run today
# Out:
# Total time: 10:08
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.539031    1.229615    0.394263    0.605736  (01:00)
# 2      0.786103    1.421046    0.484686    0.515314  (01:00)
# 3      1.034541    1.232615    0.387944    0.612056  (01:00)
# 4      1.078048    1.049834    0.416626    0.583374  (01:00)
# 5      1.007580    1.008702    0.391833    0.608167  (01:00)
# 6      0.926600    1.018305    0.447739    0.552261  (01:00)
# 7      0.864680    0.922716    0.350024    0.649976  (01:00)
# 8      0.801672    0.884186    0.331065    0.668935  (01:00)
# 9      0.708339    0.879376    0.346621    0.653379  (01:00)
# 10     0.660518    0.937851    0.339815    0.660185  (01:00)

# %%
learnM.fit_one_cycle(10, max_lr=slice(1e-6,5*1e-6)) #ran today
# Out:
# Total time: 09:57
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      2.305787    1.969458    0.827754    0.172246  (01:01)
# 2      2.274805    1.922472    0.814168    0.185832  (00:59)
# 3      2.201140    1.839077    0.779719    0.220281  (00:59)
# 4      2.096368    1.755089    0.737506    0.262494  (00:59)
# 5      2.037475    1.694287    0.704027    0.295973  (00:59)
# 6      1.975909    1.630348    0.672004    0.327996  (00:59)
# 7      1.936441    1.602275    0.661329    0.338671  (00:59)
# 8      1.887866    1.580655    0.640951    0.359049  (00:59)
# 9      1.883838    1.584095    0.647744    0.352256  (00:59)
# 10     1.883405    1.587261    0.655022    0.344978  (00:59)

# %%
#ran today
learnM.unfreeze()
learnM.lr_find()
learnM.recorder.plot()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learnM.fit_one_cycle(10, max_lr=slice(1e-3,5*1e-3))
# Out:
# Total time: 13:56
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      1.092275    0.994532    0.386220    0.613780  (01:23)
# 2      0.978854    1.075850    0.446385    0.553615  (01:23)
# 3      0.987210    1.016934    0.441533    0.558467  (01:23)
# 4      0.958199    0.961690    0.412421    0.587579  (01:23)
# 5      0.885264    1.124191    0.427462    0.572538  (01:23)
# 6      0.851956    0.915763    0.362931    0.637069  (01:23)
# 7      0.716250    0.923233    0.357593    0.642407  (01:23)
# 8      0.504728    1.069756    0.373605    0.626395  (01:23)
# 9      0.280573    1.212331    0.372149    0.627851  (01:23)
# 10     0.134130    1.284516    0.371179    0.628821  (01:23)

# %%
learnM.fit_one_cycle(10, max_lr=slice(1e-3,1e-2))
# Out:
# Total time: 13:53
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.950324    1.591043    0.376516    0.623484  (01:22)
# 2      0.915828    1.016420    0.363416    0.636584  (01:22)
# 3      0.913492    1.432181    0.386705    0.613295  (01:22)
# 4      0.880789    0.966195    0.402232    0.597768  (01:23)
# 5      0.845712    0.926577    0.385250    0.614750  (01:23)
# 6      0.750168    0.984430    0.377972    0.622028  (01:23)
# 7      0.641856    1.123178    0.400776    0.599224  (01:23)
# 8      0.533339    1.157592    0.394954    0.605046  (01:23)
# 9      0.406240    1.234754    0.393013    0.606987  (01:23)
# 10     0.359167    1.279193    0.393984    0.606017  (01:23)

# %%
learnM.fit_one_cycle(10, max_lr=slice(1e-3,16*1e-3)) # Theoretically this should work. But this is howering 54 -60%
# Out:
# Total time: 13:55
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.397207    1.405971    0.395439    0.604561  (01:23)
# 2      0.421502    1.625907    0.404658    0.595342  (01:23)
# 3      0.461481    1.925285    0.393498    0.606502  (01:23)
# 4      0.449087    1.497811    0.397380    0.602620  (01:23)
# 5      0.372830    1.727762    0.419214    0.580786  (01:23)
# 6      0.249512    2.276842    0.451722    0.548278  (01:23)
# 7      0.138849    2.282164    0.405628    0.594372  (01:23)
# 8      0.079759    2.566350    0.405628    0.594372  (01:23)
# 9      0.047821    2.590712    0.392528    0.607472  (01:23)
# 10     0.031137    2.615271    0.390102    0.609898  (01:23)

# %%
learnM.fit_one_cycle(10, max_lr=slice(1e-3,5*1e-3))
# Out:
# Total time: 13:56
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.237174    1.552972    0.395924    0.604076  (01:23)
# 2      0.365932    1.729568    0.452693    0.547307  (01:23)
# 3      0.456379    1.253188    0.410966    0.589034  (01:23)
# 4      0.445780    1.422731    0.426007    0.573993  (01:23)
# 5      0.350805    1.494545    0.403202    0.596798  (01:23)
# 6      0.218886    1.827784    0.427462    0.572538  (01:23)
# 7      0.117607    1.766317    0.402717    0.597283  (01:23)
# 8      0.055329    1.792995    0.377487    0.622513  (01:23)
# 9      0.022221    1.812524    0.362931    0.637069  (01:23)
# 10     0.012637    1.855673    0.353227    0.646773  (01:23)

# %%
learnM.fit_one_cycle(10, max_lr=slice(1e-3,1e-2))
# Out:
# Total time: 13:58
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      1.048352    1.105921    0.404173    0.595827  (01:23)
# 2      0.971723    1.156150    0.495876    0.504124  (01:23)
# 3      1.051742    1.876777    0.489083    0.510917  (01:23)
# 4      0.991800    1.400578    0.525958    0.474042  (01:24)
# 5      0.907162    0.957144    0.383794    0.616206  (01:23)
# 6      0.843936    0.966796    0.397380    0.602620  (01:23)
# 7      0.753352    1.138477    0.420184    0.579816  (01:23)
# 8      0.561015    1.041966    0.365357    0.634643  (01:23)
# 9      0.327741    1.225662    0.373605    0.626395  (01:23)
# 10     0.188048    1.260412    0.374575    0.625425  (01:23)

# %%
learnM.fit_one_cycle(10, max_lr=slice(1e-6,5*1e-6))
# Out:
# Total time: 13:53
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.012724    1.868641    0.356623    0.643377  (01:22)
# 2      0.011314    1.854207    0.360505    0.639495  (01:23)
# 3      0.017774    1.846124    0.363416    0.636584  (01:23)
# 4      0.012314    1.865436    0.353712    0.646288  (01:23)
# 5      0.010524    1.876233    0.364386    0.635614  (01:23)
# 6      0.010244    1.880449    0.348375    0.651625  (01:23)
# 7      0.009867    1.871467    0.353712    0.646288  (01:23)
# 8      0.009336    1.889313    0.361960    0.638040  (01:23)
# 9      0.009328    1.879843    0.360019    0.639981  (01:23)
# 10     0.009640    1.887688    0.364386    0.635614  (01:23)

# %%
interp = ClassificationInterpretation.from_learner(learnM)
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(13,13), dpi=80)

# %%
learnM.save('r34_mspec_unfr_le-6')

# %% [markdown]
# ## Lets try with resnet 50

# %%
learnM50 = create_cnn(data, models.resnet50, metrics=[error_rate, accuracy])
learnM50.lr_find()
learnM50.recorder.plot()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learnM50.fit_one_cycle(10, 1.6*1e-2)
# Out:
# Total time: 23:00
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      1.091100    1.012627    0.438296    0.561704  (02:31)
# 2      1.033658    1.089569    0.440744    0.559256  (02:17)
# 3      0.974429    1.093360    0.419197    0.580803  (02:16)
# 4      0.969961    1.030426    0.414789    0.585211  (02:16)
# 5      0.913235    0.931415    0.357003    0.642997  (02:16)
# 6      0.900051    0.891251    0.350637    0.649363  (02:16)
# 7      0.818496    0.892172    0.346229    0.653771  (02:16)
# 8      0.743425    0.858711    0.343291    0.656709  (02:16)
# 9      0.628180    0.876044    0.332027    0.667973  (02:16)
# 10     0.528681    0.898785    0.342801    0.657199  (02:16)

# %%
learnM50.fit_one_cycle(10, max_lr=slice(1.75*1e-2, 1e-1))
# Out:
# Total time: 22:36
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.777595    1.116123    0.379040    0.620960  (02:16)
# 2      1.147926    1.558545    0.499510    0.500490  (02:15)
# 3      1.550251    10.804362   0.698335    0.301665  (02:15)
# 4      1.299505    1.545521    0.441234    0.558766  (02:15)
# 5      1.192061    9.236832    0.410382    0.589618  (02:15)
# 6      1.101312    8.031068    0.462782    0.537218  (02:15)
# 7      0.970386    9.531952    0.373653    0.626347  (02:15)
# 8      0.853666    1.864632    0.349167    0.650833  (02:15)
# 9      0.733073    7.844522    0.343291    0.656709  (02:15)
# 10     0.659634    4.705791    0.331538    0.668462  (02:15)

# %%
learnM50.unfreeze()
learnM50.lr_find()
learnM50.recorder.plot()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learnM50.fit_one_cycle(10, max_lr=slice(1e-5, 1e-4))
# Out:
# Total time: 29:38
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.632589    3.299381    0.341332    0.658668  (02:59)
# 2      0.637963    0.970570    0.352596    0.647404  (02:57)
# 3      0.584832    2.486294    0.351616    0.648384  (02:57)
# 4      0.513438    1.037303    0.358472    0.641528  (02:57)
# 5      0.415744    1.096852    0.379530    0.620470  (02:57)
# 6      0.290474    1.144835    0.378061    0.621939  (02:57)
# 7      0.217108    1.298468    0.378061    0.621939  (02:57)
# 8      0.163142    1.151018    0.380020    0.619980  (02:57)
# 9      0.129589    1.173327    0.370715    0.629285  (02:57)
# 10     0.129410    1.405308    0.370715    0.629285  (02:57)

# %%
learnM50.fit_one_cycle(10, max_lr=slice(1e-5, 5*1e-5))
# Out:
# Total time: 29:36
# epoch  train_loss  valid_loss  error_rate  accuracy
# 1      0.124144    1.579665    0.378550    0.621450  (02:57)
# 2      0.127644    1.224909    0.384427    0.615573  (02:57)
# 3      0.133285    1.334587    0.384917    0.615083  (02:57)
# 4      0.122422    1.279375    0.367287    0.632713  (02:57)
# 5      0.092252    1.323307    0.381489    0.618511  (02:57)
# 6      0.066587    1.342172    0.387365    0.612635  (02:57)
# 7      0.053549    1.350501    0.379530    0.620470  (02:57)
# 8      0.044862    1.340514    0.380020    0.619980  (02:57)
# 9      0.038588    1.338480    0.383448    0.616552  (02:57)
# 10     0.033605    1.340440    0.386386    0.613614  (02:57)

# %% [markdown]
# ## Ideas
#
# ** Always run for 100 epochs **
#
# 1. Tempogram with ResNet-50
# 2. Use pretrained Mels spectrogram resnet with Tempogram
# 3. Remove Tender class and re-run the models
# 4. Combine Spectrogram and Tempogram in to a single NDArray and train

# %% [markdown]
# ## TEMPOGRAM

# %%
tempogram_path = Path('/home/ec2-user/SageMaker/course-v3/nbs/personal_projects/Music_Mood_Classification/tempogram')
label_path  = Path('/home/ec2-user/SageMaker/course-v3/nbs/personal_projects/Music_Mood_Classification/input_label.csv')

# %%
dataT = ImageDataBunch.from_csv(tempogram_path.parent,
                               tempogram_path.name, 
                               csv_labels = str(label_path), suffix='.png',size=224, bs=128)

# %%
dataT.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList
# y: CategoryList (8117 items)
# [Category Angry, Category Tender, Category Sad, Category Tender, Category Happy]...
# Path: /home/ec2-user/SageMaker/course-v3/nbs/personal_projects/Music_Mood_Classification
# x: ImageItemList (8117 items)
# [Image (3, 277, 285), Image (3, 277, 285), Image (3, 277, 285), Image (3, 277, 285), Image (3, 277, 285)]...
# Path: /home/ec2-user/SageMaker/course-v3/nbs/personal_projects/Music_Mood_Classification;
#
# Valid: LabelList
# y: CategoryList (2029 items)
# [Category Tender, Category Happy, Category Tender, Category Sad, Category Tender]...
# Path: /home/ec2-user/SageMaker/course-v3/nbs/personal_projects/Music_Mood_Classification
# x: ImageItemList (2029 items)
# [Image (3, 277, 285), Image (3, 277, 285), Image (3, 277, 285), Image (3, 277, 285), Image (3, 277, 285)]...
# Path: /home/ec2-user/SageMaker/course-v3/nbs/personal_projects/Music_Mood_Classification;
#
# Test: None

# %%
dataT.show_batch(rows=3, figsize=(7,6))

# %%
from  fastai.vision import models

learnT = create_cnn(dataT, models.resnet50, metrics=[error_rate, accuracy])
learnT.lr_find()
learnT.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-220b056c45e5> in <module>
#       2
#       3 learnT = create_cnn(dataT, models.resnet50, metrics=[error_rate, accuracy])
# ----> 4 learnT.lr_find()
#       5 learnT.recorder.plot()
#
# ~/SageMaker/envs/fastai/lib/python3.7/site-packages/fastai/train.py in lr_find(learn, start_lr, end_lr, num_it, stop_div, **kwargs)
#      30     cb = LRFinder(learn, start_lr, end_lr, num_it, stop_div)
#      31     a = int(np.ceil(num_it/len(learn.data.train_dl)))
# ---> 32     learn.fit(a, start_lr, callbacks=[cb], **kwargs)
#      33
#      34 def to_fp16(learn:Learner, loss_scale:float=512., flat_master:bool=False)->Learner:
#
# ~/SageMaker/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
# ...

# %%
#0.01 to 0.1 ==> 0.05
learnT.fit_one_cycle(25, 5e-2)
# Out:
# Total time: 14:43 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.431180</th>
#     <th>1.358658</th>
#     <th>0.544603</th>
#     <th>0.455397</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.399520</th>
#     <th>1.762478</th>
#     <th>0.602267</th>
#     <th>0.397733</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.395217</th>
#     <th>1.469505</th>
#     <th>0.585017</th>
#     <th>0.414983</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.371458</th>
#     <th>1.355568</th>
#     <th>0.522425</th>
#     <th>0.477575</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>1.441435</th>
#     <th>1.898022</th>
#     <th>0.705766</th>
#     <th>0.294234</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>1.521158</th>
#     <th>1.714800</th>
#     <th>0.644160</th>
#     <th>0.355840</th>
# ...

# %%
learnT.fit_one_cycle(25, max_lr=slice(5e-2, 1e-1))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='25', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       28.00% [7/25 04:06<10:33]
#     </div>
#
# <table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.066987</th>
#     <th>1.395801</th>
#     <th>0.523411</th>
# ...

# %%
# Note

LR (5e-2) Acc: 50
